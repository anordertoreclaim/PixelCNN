# %%
from datasets import load_dataset
import torch

# %%
ds=load_dataset("nielsr/CelebA-faces")
ds
# Out:
# Downloading metadata:   0%|          | 0.00/667 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/462M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/463M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/463M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/202599 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['image'],
#         num_rows: 202599
#     })
# })

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
ds = ds.with_format("torch",device=device)
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image'],
#         num_rows: 202599
#     })
# })

# %%
ds['train'][0]['image'].shape
# Out:
# torch.Size([218, 178, 3])

# %%
import deeplake

# %%
ds = deeplake.load("hub://activeloop/celeb-a-test")
ds
# Out:
# /
# Opening dataset in read-only mode as you don't have write permissions.
# \
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/celeb-a-test
# -
# hub://activeloop/celeb-a-test loaded successfully.
# /home/biggergig/micromamba/envs/torch/lib/python3.10/site-packages/deeplake/api/dataset.py:763: UserWarning: Dataset has more than 20 tensors. Skipping integrity check. Specify `check_integrity=True` to perform integrity check.
#   warnings.warn(
# Dataset(path='hub://activeloop/celeb-a-test', read_only=True, tensors=['images', 'boxes', 'keypoints', 'clock_shadow', 'arched_eyebrows', 'attractive', 'bags_under_eyes', 'bald', 'bangs', 'big_lips', 'big_nose', 'black_hair', 'blond_hair', 'blurry', 'brown_hair', 'bushy_eyebrows', 'chubby', 'double_chin', 'eyeglasses', 'goatee', 'gray_hair', 'heavy_makeup', 'high_cheekbones', 'male', 'mouth_slightly_open', 'mustache', 'narrow_eyes', 'no_beard', 'oval_face', 'pale_skin', 'pointy_nose', 'receding_hairline', 'rosy_cheeks', 'sideburns', 'smiling', 'straight_hair', 'wavy_hair', 'wearing_earrings', 'wearing_hat', 'wearing_lipstick', 'wearing_necklace', 'wearing_necktie', 'young'])

# %%
import wandb

# %%
run = wandb.init(project="PixelCNN")

artifact = wandb.Artifact("celeba_model", type='model')
artifact.add_dir(local_path="model/test_epoch_1")
run.log_artifact(artifact)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: anshuman-dash (pixelcnn). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/home/user/PixelCNN-testing/wandb/run-20240308_081640-4xaodiqw</code>
# Syncing run <strong><a href='https://wandb.ai/pixelcnn/PixelCNN/runs/4xaodiqw' target="_blank">copper-leaf-174</a></strong> to <a href='https://wandb.ai/pixelcnn/PixelCNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/pixelcnn/PixelCNN' target="_blank">https://wandb.ai/pixelcnn/PixelCNN</a>
#  View run at <a href='https://wandb.ai/pixelcnn/PixelCNN/runs/4xaodiqw' target="_blank">https://wandb.ai/pixelcnn/PixelCNN/runs/4xaodiqw</a>
